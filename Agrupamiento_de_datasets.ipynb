# %% [markdown]
# <a href="https://colab.research.google.com/github/Cesar17188/EDA/blob/master/Agrupamiento_de_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Llamamos el set de datos público
import pandas as pd
import altair as alt
Chicago_data = 'https://raw.githubusercontent.com/terranigmark/curso-analisis-exploratorio-datos-platzi/main/Traffic_Crashes1.csv'
Chicago_df=pd.read_csv(Chicago_data)
Chicago_df['CRASH_DATE'] = Chicago_df['CRASH_DATE'].apply(lambda x: pd.to_datetime(x,errors='coerce', utc=True))

# %%
Chicago_df.head()
# Out:
#    Unnamed: 0  ...   date_real
# 0      290702  ...  2017-02-14
# 1      405524  ...  2019-08-13
# 2      261834  ...  2019-05-22
# 3       38519  ...  2017-06-14
# 4      420197  ...  2018-05-03
#
# [5 rows x 51 columns]

# %%
report_1 = Chicago_df.groupby(['LIGHTING_CONDITION', 'REPORT_TYPE', 'CRASH_HOUR']).agg({'NUM_UNITS':'sum'})

# %%
report_1 = report_1.reset_index()
report_1
# Out:
#     LIGHTING_CONDITION                 REPORT_TYPE CRASH_HOUR NUM_UNITS
#                                                                     sum min max
# 0             DARKNESS                     AMENDED         20         2   2   2
# 1             DARKNESS  NOT ON SCENE (DESK REPORT)          0        97   1   2
# 2             DARKNESS  NOT ON SCENE (DESK REPORT)          1        86   1   2
# 3             DARKNESS  NOT ON SCENE (DESK REPORT)          2        64   1   5
# 4             DARKNESS  NOT ON SCENE (DESK REPORT)          3        57   1   2
# ..                 ...                         ...        ...       ...  ..  ..
# 286            UNKNOWN                    ON SCENE         19         9   1   2
# 287            UNKNOWN                    ON SCENE         20        10   2   2
# 288            UNKNOWN                    ON SCENE         21        10   2   2
# 289            UNKNOWN                    ON SCENE         22        20   2   3
# 290            UNKNOWN                    ON SCENE         23         6   2   2
#
# [291 rows x 6 columns]

# %%
alt.Chart(report_1).mark_bar().encode(
    x='LIGHTING_CONDITION',
    y='NUM_UNITS',
    color='REPORT_TYPE'
).properties(width=220)
# Out:
# alt.Chart(...)

# %%
report_1 = Chicago_df.groupby(['LIGHTING_CONDITION', 'REPORT_TYPE', 'CRASH_HOUR']).agg({'NUM_UNITS':['sum','min','max']})

# %%
report_1
# Out:
#                                                          NUM_UNITS
#                                                                sum min max
# LIGHTING_CONDITION REPORT_TYPE                CRASH_HOUR
# DARKNESS           AMENDED                    20                 2   2   2
#                    NOT ON SCENE (DESK REPORT) 0                 97   1   2
#                                               1                 86   1   2
#                                               2                 64   1   5
#                                               3                 57   1   2
# ...                                                            ...  ..  ..
# UNKNOWN            ON SCENE                   19                 9   1   2
#                                               20                10   2   2
#                                               21                10   2   2
#                                               22                20   2   3
#                                               23                 6   2   2
#
# [291 rows x 3 columns]
