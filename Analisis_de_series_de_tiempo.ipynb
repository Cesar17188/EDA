# %% [markdown]
# <a href="https://colab.research.google.com/github/Cesar17188/EDA/blob/master/Analisis_de_series_de_tiempo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis de Series de Tiempo (TSA)
#
# Obtendremos la información de la siguiente página: https://www.quandi.com/

# %% [markdown]
# Federal Reserve Economic Data (FRED) USA

# %%
# !pip install quandl

# %%
import quandl
QUANDL_API_KEY = 'YcBEHByjNwDZiuK_u-M2' # Your Quandl key here
quandl.ApiConfig.api_key = QUANDL_API_KEY

# %%
quandl.get("FRED/GDP")
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2020-04-01  19477.444
# 2020-07-01  21138.574
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22731.369
#
# [298 rows x 1 columns]

# %%
df_real=quandl.get("CHRIS/CME_GC1",column_index=6,collapse='weakly',start_date='2010-01-01')

# %%
df_real.resample('MS').ffill().dropna()
# Out:
#             Settle
# Date
# 2010-02-01  1104.3
# 2010-03-01  1118.3
# 2010-04-01  1125.1
# 2010-05-01  1180.7
# 2010-06-01  1224.8
# ...            ...
# 2021-02-01  1866.0
# 2021-03-01  1725.8
# 2021-04-01  1728.4
# 2021-05-01  1767.7
# 2021-06-01  1902.9
#
# [137 rows x 1 columns]

# %%
ventana_t=df_real.rolling(4)
media_df_real=ventana_t.mean()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
plt.plot(df_real,label='original')
plt.plot(media_df_real,label='media')
plt.legend()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
season_variablels=seasonal_decompose(df_real,freq=12)

# %%
season_variablels.plot()
